# %%
from langgraph.graph import Stategraph,START,END
from typing import Typedist,annotated
from  langchain_core.messages import BaseMessage,HummanMessage
form langgraph.graph.messages import add_messages
from langchain_openai import ChatOpenAI
